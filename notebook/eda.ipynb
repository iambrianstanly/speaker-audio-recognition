# %%
import librosa

# %%
path = r"..\data\train\Benjamin\0.wav"

y, s = librosa.load(path, sr=None)
s
# Out:
# 16000

# %% [markdown]
# dataset contains audio sampled at 16Khz 1sec audio samples.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
plt.plot(range(len(y)), y)
plt.ylabel("Amplitude")
plt.xlabel("Time")
plt.grid(True)
plt.show()

# %%
import os
for (root,dir,file) in  os.walk("../data/train"):
    break

dir
# Out:
# ['Benjamin', 'Jens', 'Julia', 'Margaret', 'Nelson']

# %% [markdown]
# 5 classes

# %%
import os
j = 0
for (root,_,file) in  os.walk("../data/train"):
    if not file:
        continue
    else:
        for i,p in enumerate(file):
            path = os.path.join(root,p)
            # print(path)
        j+=(i+1)

print(f"total {j} number of samples")
# Out:
# total 6000 number of samples

# %% [markdown]
# training samples contain 6000 samples
